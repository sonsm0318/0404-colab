# %% [markdown]
# quiz 1

# %%
asdf = []
for i in range (1,5):
  asdf.append("★")
for i in range (1,4):
  print(asdf)
# Out:
# ['★', '★', '★', '★']
# ['★', '★', '★', '★']
# ['★', '★', '★', '★']

# %% [markdown]
# quiz 2

# %%
for i in range (1,4):
   print("★★★★")
# Out:
# ★★★★
# ★★★★
# ★★★★

# %% [markdown]
# quiz 3

# %%
for i in range (1,4):
  for j in range (1,5):
    print("★", end = "")
  print()
# Out:
# ★★★★
# ★★★★
# ★★★★

# %% [markdown]
# quiz 4

# %%
star = '*'
horizental_stars = star * 3
for i in range(4):
  print(horizental_stars)
# Out:
# ***
# ***
# ***
# ***

# %% [markdown]
# quiz 5-1

# %%
import math
radius = float(input("반지름 길이를 입력 : "))
height = float(input("높이를 입력 : "))
volume = float(math.pi * (radius ** 2) * height)
print(volume)
# Out:
# 반지름 길이를 입력 : 2
# 높이를 입력 : 2
# 25.132741228718345

# %% [markdown]
# quiz 5-2

# %%
import math
radius = []
height = []
while True:
 r = input("반지름 입력 (종료하려면 q 입력) : ")
 if r == "q":
  break
 r = float (r)
 radius.append(r)
 h = input("높이 입력 (종료하려면 q 입력) : ")
 if h == "q":
  break
 h = float (h)
 height.append(h)
# Out:
# 반지름 입력 (종료하려면 q 입력) : 2
# 높이 입력 (종료하려면 q 입력) : 3
# 반지름 입력 (종료하려면 q 입력) : 4
# 높이 입력 (종료하려면 q 입력) : 2
# 반지름 입력 (종료하려면 q 입력) : q

# %% [markdown]
# quiz 6-1

# %%
import datetime
x = datetime.datetime.now()
print(x)
# Out:
# 2024-04-04 05:58:26.626183

# %% [markdown]
# quiz 6-2

# %%
import datetime
weekday_index = x.weekday()
weekdays = ["월", "화", "수", "목", "금", "토", "일"]
now = datetime.datetime.now()
year = now.year
month = now.month
day = now.day
hour = now.hour
minute = now.minute
second = now.second

print(year,"/",month,"/",day," ",weekdays[weekday_index]," ",hour,":",minute,":",second)
# Out:
# 2024 / 4 / 4   목   6 : 9 : 3

# %% [markdown]
# quiz 6-3

# %%
import datetime
weekday_index = x.weekday()
weekdays = ["월", "화", "수", "목", "금", "토", "일"]
now = datetime.datetime.now()
year = now.year
month = now.month
day = now.day
hour = now.hour
minute = now.minute
second = now.second

print(year)
print(month)
print(day)
print(weekdays[weekday_index])
print(hour)
print(minute)
print(second)
# Out:
# 2024
# 4
# 4
# 목
# 6
# 9
# 6

# %% [markdown]
# quiz 7

# %%
student_heights = (165, 172, 168, 175, 160, 180, 173, 169, 176, 171)
print("170 보다 큰 학생들의 키:")
for height in student_heights:
    if height > 170:
        print(height)
# Out:
# 170 보다 큰 학생들의 키:
# 172
# 175
# 180
# 173
# 176
# 171

# %% [markdown]
# quiz 8

# %%
def q1():
  asdf = []
  for i in range (1,5):
   asdf.append("★")
  for i in range (1,4):
    print(asdf)

q1()
# Out:
# ['★', '★', '★', '★']
# ['★', '★', '★', '★']
# ['★', '★', '★', '★']

# %%
def q2():
 for i in range (1,4):
   print("★★★★")

q2()
# Out:
# ★★★★
# ★★★★
# ★★★★

# %%
def q3():
 for i in range (1,4):
  for j in range (1,5):
    print("★", end = "")
  print()

q3()
# Out:
# ★★★★
# ★★★★
# ★★★★

# %%
def q4():
 star = '*'
 horizental_stars = star * 3
 for i in range(4):
  print(horizental_stars)

q4()
# Out:
# ***
# ***
# ***
# ***

# %%
def q5_1():
 import math
 radius = float(input("반지름 길이를 입력 : "))
 height = float(input("높이를 입력 : "))
 volume = float(math.pi * (radius ** 2) * height)
 print(volume)
q5_1()
# Out:
#   File "<ipython-input-68-b946b4b67f6a>", line 1
#     def q5_1()
#               ^
# SyntaxError: expected ':'

# %%
def q5_2():
 import math
 radius = []
 height = []
 while True:
  r = input("반지름 입력 (종료하려면 q 입력) : ")
  if r == "q":
   break
  r = float (r)
  radius.append(r)
  h = input("높이 입력 (종료하려면 q 입력) : ")
  if h == "q":
   break
  h = float (h)
  height.append(h)
q5_2()

# %%
def q6_1():
  import datetime
  x = datetime.datetime.now()
  print(x)
q6_1()

# %%
def q6_2():
 import datetime
 weekday_index = x.weekday()
 weekdays = ["월", "화", "수", "목", "금", "토", "일"]
 now = datetime.datetime.now()
 year = now.year
 month = now.month
 day = now.day
 hour = now.hour
 minute = now.minute
 second = now.second

 print(year,"/",month,"/",day," ",weekdays[weekday_index]," ",hour,":",minute,":",second)
q6_2()

# %%
def q6_3():
 import datetime
 weekday_index = x.weekday()
 weekdays = ["월", "화", "수", "목", "금", "토", "일"]
 now = datetime.datetime.now()
 year = now.year
 month = now.month
 day = now.day
 hour = now.hour
 minute = now.minute
 second = now.second

 print(year)
 print(month)
 print(day)
 print(weekdays[weekday_index])
 print(hour)
 print(minute)
 print(second)
q6_3()

# %%
def q7():
 student_heights = (165, 172, 168, 175, 160, 180, 173, 169, 176, 171)
 print("170 보다 큰 학생들의 키:")
 for height in student_heights:
    if height > 170:
        print(height)
q7()
